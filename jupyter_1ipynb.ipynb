# %% [markdown]
# <a href="https://colab.research.google.com/github/sarnaikrevati18/python-1/blob/main/jupyter_1ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
print(type(a))

b=10.5
print(type(b))

c="revati"
print(type(c))

d=True
print(type(d))

f=[1,2,3]
print(type(f))

h={"name":"revati"}
print(type(h))

i={"revati"}
print(type(i))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'list'>
# <class 'dict'>
# <class 'set'>
