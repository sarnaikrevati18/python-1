# %% [markdown]
# <a href="https://colab.research.google.com/github/sarnaikrevati18/python-1/blob/main/jupyter_5ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# c  = input("Enter a string: ")

# Calculate length
length = len("revati
")
print("Length of the string is:", length)
# Out:
# Length of the string is: 5

# %%
# Take string input from user
string = input("Enter a string: ")

# Check length condition
if len(string) < 2:
    print("Empty string")
else:
    result = string[:2] + string[-2:]
    print("New string is:", result)
# Out:
# Enter a string: 7
# Empty string

# %%
# Take two strings as input
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")

# Concatenate strings
result = str1 + str2
print("Concatenated string is:", result)
# Out:
# Enter first string: 7
# Enter second string: 8
# Concatenated string is: 78
