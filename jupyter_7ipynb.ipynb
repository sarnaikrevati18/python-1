# %% [markdown]
# <a href="https://colab.research.google.com/github/sarnaikrevati18/python-1/blob/main/jupyter_7ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Creating a tuple
L = (1, 2, 3, 4)

# Length
print("Length:", len(L))

# Concatenation
L2 = (5, 6)
print("Concatenation:", L + L2)

# Repetition
print("Repetition:", L * 2)

# Membership
print("Is 3 in tuple?", 3 in L)
# Out:
# Length: 4
# Concatenation: (1, 2, 3, 4, 5, 6)
# Repetition: (1, 2, 3, 4, 1, 2, 3, 4)
# Is 3 in tuple? True

# %%
L = (10, 20, 30, 40, 50)

# Indexing
print("First element:", L[0])

# Negative indexing
print("Last element:", L[-1])

# Slicing
print("Sliced tuple:", L[1:4])

# Iteration
print("Elements in tuple:")
for i in t:
    print(i)
# Out:
# First element: 10
# Last element: 50
# Sliced tuple: (20, 30, 40)
# Elements in tuple:
# 1
# 2
# 3
# 4

# %%
L = (1, 2, 3)

# Tuples are immutable
# L[0] = 10   # This will give error

print("Original tuple:", L)

# Deleting tuple
del L

# print(L)  # This will give error because tuple is deleted
# Out:
# Original tuple: (1, 2, 3)

# %%
L = (5, 2, 9, 1)

print("Length:", len(L))
print("Maximum:", max(L))
print("Minimum:", min(L))
print("Tuple conversion:", tuple([1, 2, 3]))
# Out:
# Length: 4
# Maximum: 9
# Minimum: 1
# Tuple conversion: (1, 2, 3)
