# %%
a=10 
b=20
c=a+b
print("addition=",c)
# Out:
# addition= 30

# %%
a=100 
name="revati"
print("type:",type(a))
print("type:",type(name))
# Out:
# type: <class 'int'>
# type: <class 'str'>

# %%
a=10
b=float(a)
print("value=",a)
print("after type casting to float=",b)
print("type of b=",type(b))
# Out:
# value= 10
# after type casting to float= 10.0
# type of b= <class 'float'>

# %%
a=10
b=5
print(a>5 and b>2)
print(a>5 or b>2)
print(not(a>5))
# Out:
# True
# True
# False
